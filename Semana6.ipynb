# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Documentos_ITA\\JUNIOR'

# %%
ppf = pd.read_csv('Spotify 2010 - 2019 Top 100.csv')

# %%
import seaborn as sns
# %matplotlib inline
ppf = pd.read_csv('Spotify 2010 - 2019 Top 100.csv')
ppf.head(10)
# Out:
#                                            title           artist  \
# 0                  STARSTRUKK (feat. Katy Perry)            3OH!3
# 1                    My First Kiss (feat. Ke$ha)            3OH!3
# 2                                I Need A Dollar       Aloe Blacc
# 3  Airplanes (feat. Hayley Williams of Paramore)            B.o.B
# 4              Nothin' on You (feat. Bruno Mars)            B.o.B
# 5                     Magic (feat. Rivers Cuomo)            B.o.B
# 6                           The Time (Dirty Bit)  Black Eyed Peas
# 7                                        Imma Be  Black Eyed Peas
# 8                            Talking to the Moon       Bruno Mars
# 9                           Just the Way You Are       Bruno Mars
#
#      top genre  year released       added    bpm  nrgy  dnce   dB  live   val  \
# 0    dance pop         2009.0  2022‑02‑17  140.0  81.0  61.0 -6.0  23.0  23.0
# 1    dance pop         2010.0  2022‑02‑17  138.0  89.0  68.0 -4.0  36.0  83.0
# ...

# %%
sns.distplot(ppf['nrgy'] , kde=False, bins = 100)
# Out:
# c:\Users\kika\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='nrgy'>

# %%
sns.distplot(ppf['dnce'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='dnce'>

# %%
sns.distplot(ppf['year released'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='year released'>

# %%
sns.distplot(ppf['bpm'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='bpm'>

# %%
sns.distplot(ppf['dB'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='dB'>

# %%
sns.distplot(ppf['live'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='live'>

# %%
sns.distplot(ppf['val'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='val'>

# %%
sns.distplot(ppf['dur'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='dur'>

# %%
sns.distplot(ppf['acous'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='acous'>

# %%
sns.distplot(ppf['spch'] , kde=False, bins = 100)
# Out:
# <AxesSubplot:xlabel='spch'>

# %%
sns.jointplot(x = 'dnce', y = 'live', data = ppf)

# %%
sns.jointplot(x = 'year released', y = 'bpm', data = ppf, kind = 'hex')

# %%
sns.jointplot(x = 'nrgy', y = 'pop', data = ppf, kde=False, kind = 'kde')
# Out:
# c:\Users\kika\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'kde'
#   cset = contour_func(

# %%
sns.pairplot(ppf, hue = 'artist type', palette = 'coolwarm')

# %%
sns.rugplot(ppf['bpm'])
# Out:
# <AxesSubplot:xlabel='bpm'>

# %%
sns.barplot(x='bpm', y='dur', data = ppf, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='bpm', ylabel='dur'>

# %%
sns.countplot(x ='year released', data = ppf)
# Out:
# <AxesSubplot:xlabel='year released', ylabel='count'>

# %%
sns.countplot(x = 'artist type', data = ppf)
# Out:
# <AxesSubplot:xlabel='artist type', ylabel='count'>

# %%
sns.boxplot(x = 'artist type', y='year released',data = ppf)
# Out:
# <AxesSubplot:xlabel='artist type', ylabel='year released'>

# %%
sns.violinplot(x='artist type',y ='dur',data = ppf,split = True)
# Out:
# <AxesSubplot:xlabel='artist type', ylabel='dur'>

# %%
sns.violinplot(x='artist type',y ='bpm',data = ppf,split = True)
# Out:
# <AxesSubplot:xlabel='artist type', ylabel='bpm'>

# %%
sns.violinplot(x='artist type',y ='dur',data = ppf,jitter = True)
# Out:
# <AxesSubplot:xlabel='artist type', ylabel='dur'>

# %%
sns.swarmplot(x = 'artist type', y= 'bpm', data = ppf, color = 'purple')
# Out:
# c:\Users\kika\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 53.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\kika\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='artist type', ylabel='bpm'>

# %%
sns.factorplot(x = 'nrgy', y ='artist type', data = ppf, kind = 'bar')
# Out:
# c:\Users\kika\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
